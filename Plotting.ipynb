# %%
from nilearn.plotting import plot_roi, plot_stat_map, plot_glass_brain
from glob import glob
# %matplotlib inline

# %%
for map_file in glob("/Users/adleman/Downloads/data/derivatives/task/Group/group.gfeat/cope1.feat/t*.nii.gz")[:10]:
    print(map_file)
    plot_stat_map(map_file, threshold=3.1)
# Out:
# /Users/adleman/Downloads/data/derivatives/task/Group/group.gfeat/cope1.feat/thresh_zstat1.nii.gz
# /Users/adleman/Downloads/data/derivatives/task/Group/group.gfeat/cope1.feat/thresh_zstat2.nii.gz

# %% [markdown]
# Adjust for loop to plot the same cut coordinates for all maps

# %%
plot_roi?

# %%
for map_file in glob("/Users/adleman/Downloads/data/derivatives/task/Group/group.gfeat/cope1.feat/stats/t*.nii.gz")[:10]:
    print(map_file)
    plot_stat_map(map_file, threshold=3.1, cut_coords=(0,0,0))
# Out:
# /Users/adleman/Downloads/data/derivatives/task/Group/group.gfeat/cope1.feat/stats/tdof_t1.nii.gz
# /Users/adleman/Downloads/data/derivatives/task/Group/group.gfeat/cope1.feat/stats/tdof_t2.nii.gz
# /Users/adleman/Downloads/data/derivatives/task/Group/group.gfeat/cope1.feat/stats/tstat1.nii.gz
# /Users/adleman/Downloads/data/derivatives/task/Group/group.gfeat/cope1.feat/stats/tstat2.nii.gz

# %%
for map_file in glob("/Users/adleman/Downloads/data/derivatives/task/Group/group.gfeat/cope1.feat/t*.nii.gz")[:10]:
    plot_glass_brain(map_file, threshold=0)
